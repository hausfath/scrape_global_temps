# %%
import numpy as np
import pandas as pd
import ftplib, io, gzip, os
from scipy.io import FortranFile

os.chdir('/Users/hausfath/Desktop/Climate Science/GHCN Monthly/')

# %%
def calc_lat_weights(size):    
    lats = np.arange(-90 + size/2., 90+size/2., size)
    weights = np.empty([len(lats)])
    i = 0
    for lat in lats:
        weight = (np.sin((lat + size / 2.0) * np.pi / 180.) -
                  np.sin((lat - size / 2.0) * np.pi / 180.))
        weights[i] = weight
        i += 1
    return weights


def fetch_ensemble_member(member):
    member = str(member).zfill(4)
    ftp_host = 'ftp.ncei.noaa.gov'
    
    with ftplib.FTP(host=ftp_host) as ftpconn:
        ftpconn.login()
    
        ftp_file = '/pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.'+member+'.gz'
        print(ftp_file)
    
        response = io.BytesIO()
        
        try:
            ftpconn.retrbinary('RETR '+ftp_file, response.write)
        except ftplib.error_perm as err:
            if str(err).startswith('550 '):
                print('ERROR:', err)
            else:
                raise
    
        response.seek(0)        
        with gzip.open(response, 'rb') as f:
            data = np.frombuffer(f.read(), dtype='>f')
        
    return data


def id_invalid():
    invalid = [0]
    for t in range(2593, 4274912, 2594):
        invalid.append(t)
        invalid.append(t + 1)
    return invalid[0:3296]


def calc_mean(data):
    valid = np.delete(data, id_invalid()) #remove blanks
    anoms = np.reshape(valid,(1648, 36, 72))
    lat_means = np.mean(anoms, axis=2)
    weights = calc_lat_weights(5.)
    global_mean = np.average(lat_means, axis=1, weights=weights)
    return global_mean

# %%
results = []

for member in range(1, 1001):
    data = fetch_ensemble_member(member)
    results.append(calc_mean(data))

results = np.vstack(results)
np.savetxt('noaa_ensemble_members.csv', np.swapaxes(results,0,1), delimiter=",")
# Out:
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0001.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0002.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0003.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0004.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0005.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0006.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0007.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0008.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0009.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0010.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0011.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0012.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0013.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0014.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0015.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0016.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0017.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0018.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0019.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0020.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0021.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0022.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0023.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0024.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0025.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0026.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0027.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0028.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0029.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0030.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0031.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0032.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0033.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0034.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0035.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0036.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0037.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0038.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0039.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0040.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0041.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0042.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0043.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0044.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0045.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0046.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0047.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0048.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0049.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0050.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0051.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0052.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0053.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0054.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0055.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0056.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0057.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0058.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0059.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0060.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0061.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0062.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0063.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0064.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0065.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0066.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0067.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0068.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0069.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0070.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0071.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0072.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0073.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0074.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0075.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0076.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0077.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0078.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0079.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0080.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0081.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0082.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0083.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0084.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0085.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0086.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0087.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0088.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0089.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0090.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0091.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0092.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0093.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0094.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0095.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0096.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0097.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0098.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0099.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0100.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0101.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0102.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0103.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0104.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0105.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0106.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0107.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0108.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0109.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0110.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0111.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0112.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0113.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0114.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0115.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0116.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0117.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0118.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0119.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0120.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0121.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0122.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0123.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0124.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0125.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0126.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0127.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0128.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0129.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0130.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0131.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0132.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0133.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0134.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0135.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0136.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0137.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0138.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0139.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0140.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0141.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0142.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0143.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0144.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0145.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0146.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0147.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0148.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0149.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0150.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0151.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0152.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0153.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0154.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0155.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0156.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0157.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0158.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0159.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0160.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0161.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0162.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0163.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0164.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0165.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0166.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0167.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0168.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0169.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0170.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0171.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0172.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0173.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0174.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0175.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0176.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0177.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0178.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0179.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0180.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0181.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0182.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0183.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0184.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0185.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0186.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0187.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0188.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0189.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0190.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0191.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0192.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0193.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0194.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0195.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0196.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0197.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0198.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0199.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0200.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0201.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0202.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0203.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0204.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0205.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0206.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0207.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0208.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0209.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0210.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0211.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0212.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0213.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0214.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0215.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0216.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0217.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0218.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0219.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0220.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0221.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0222.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0223.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0224.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0225.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0226.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0227.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0228.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0229.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0230.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0231.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0232.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0233.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0234.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0235.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0236.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0237.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0238.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0239.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0240.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0241.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0242.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0243.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0244.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0245.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0246.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0247.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0248.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0249.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0250.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0251.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0252.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0253.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0254.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0255.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0256.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0257.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0258.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0259.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0260.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0261.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0262.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0263.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0264.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0265.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0266.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0267.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0268.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0269.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0270.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0271.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0272.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0273.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0274.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0275.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0276.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0277.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0278.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0279.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0280.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0281.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0282.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0283.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0284.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0285.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0286.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0287.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0288.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0289.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0290.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0291.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0292.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0293.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0294.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0295.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0296.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0297.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0298.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0299.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0300.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0301.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0302.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0303.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0304.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0305.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0306.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0307.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0308.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0309.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0310.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0311.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0312.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0313.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0314.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0315.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0316.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0317.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0318.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0319.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0320.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0321.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0322.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0323.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0324.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0325.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0326.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0327.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0328.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0329.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0330.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0331.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0332.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0333.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0334.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0335.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0336.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0337.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0338.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0339.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0340.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0341.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0342.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0343.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0344.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0345.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0346.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0347.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0348.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0349.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0350.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0351.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0352.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0353.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0354.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0355.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0356.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0357.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0358.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0359.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0360.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0361.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0362.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0363.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0364.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0365.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0366.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0367.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0368.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0369.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0370.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0371.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0372.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0373.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0374.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0375.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0376.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0377.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0378.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0379.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0380.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0381.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0382.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0383.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0384.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0385.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0386.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0387.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0388.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0389.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0390.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0391.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0392.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0393.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0394.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0395.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0396.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0397.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0398.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0399.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0400.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0401.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0402.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0403.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0404.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0405.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0406.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0407.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0408.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0409.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0410.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0411.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0412.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0413.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0414.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0415.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0416.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0417.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0418.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0419.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0420.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0421.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0422.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0423.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0424.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0425.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0426.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0427.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0428.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0429.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0430.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0431.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0432.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0433.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0434.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0435.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0436.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0437.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0438.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0439.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0440.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0441.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0442.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0443.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0444.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0445.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0446.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0447.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0448.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0449.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0450.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0451.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0452.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0453.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0454.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0455.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0456.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0457.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0458.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0459.gz
# /pub/data/cmb/ersst/v5/2019.ngtv5.ensemble/temp.ano.merg5.dat.0460.gz
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-384-60b5477e54d8> in <module>
#       2
#       3 for member in range(1, 1001):
# ----> 4     data = fetch_ensemble_member(member)
#       5     results.append(calc_mean(data))
#       6
#
# <ipython-input-381-3d9f0d18f9f3> in fetch_ensemble_member(member)
#      24
#      25         try:
# ---> 26             ftpconn.retrbinary('RETR '+ftp_file, response.write)
#      27         except ftplib.error_perm as err:
#      28             if str(err).startswith('550 '):
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ftplib.py in retrbinary(self, cmd, callback, blocksize, rest)
#     440         """
#     441         self.voidcmd('TYPE I')
# --> 442         with self.transfercmd(cmd, rest) as conn:
#     443             while 1:
#     444                 data = conn.recv(blocksize)
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ftplib.py in transfercmd(self, cmd, rest)
#     397     def transfercmd(self, cmd, rest=None):
#     398         """Like ntransfercmd() but returns only the socket."""
# --> 399         return self.ntransfercmd(cmd, rest)[0]
#     400
#     401     def login(self, user = '', passwd = '', acct = ''):
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ftplib.py in ntransfercmd(self, cmd, rest)
#     359             host, port = self.makepasv()
#     360             conn = socket.create_connection((host, port), self.timeout,
# --> 361                                             source_address=self.source_address)
#     362             try:
#     363                 if rest is not None:
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
#     727         try:
# --> 728             raise err
#     729         finally:
#     730             # Break explicitly a reference cycle
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# TimeoutError: [Errno 60] Operation timed out

# %%
#For reading monthly uncertainty file; ignore unless you need this for some reason.
fname = 'noaaglobaltemp5.unc.glb.dat'
data = np.fromfile(fname, dtype='>f')
np.savetxt('noaa_uncertainty.csv', data, delimiter=",")
data
